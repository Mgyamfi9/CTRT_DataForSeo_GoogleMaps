# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your connection details
server = 'ctrt-sqlserver.database.windows.net'
database = 'ctrt-sqldb'
username = 'CTRT-admin'
password = 'Hso2Ghana'
crime_Kumasi = 'silver.MG_Crimes_Kumasi'
crime_Accra = 'silver.MG_Crimes_Accra'
port = '1433'  # Default is 1433, e.g., '1433'

# Create the connection string for SQLAlchemy
connection_string = (
    f"mssql+pyodbc://{username}:{password}@{server}:{port}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# Establish the connection using SQLAlchemy create_engine
engine = create_engine(connection_string, echo=False)  # Set echo=True for debugging

# Define the query
query1 = f"SELECT * FROM {crime_Kumasi}"
query2 = f"SELECT * FROM {crime_Accra}"

# Execute the query and load the data into a DataFrame
Kumasi_crime_df = pd.read_sql(query1, engine)
Accra_crime_df = pd.read_sql(query2, engine)

# %%
Accra_crime_df.head(5)
# Out:
#                                                title  \
# 0  How gentrification is forcing Ghanaians out of...
# 1  Court remands footballer, 3 others in police c...
# 2  Sowutuom, Nima: Canadian government warns citi...
# 3  Police on manhunt for lone robber terrorising ...
# 4  Ablekuma Bullion Van Robbery: How Police Arres...
#
#                                                  url  \
# 0  https://www.opendemocracy.net/en/5050/ghana-ge...
# 1  https://3news.com/news/crime/court-remands-foo...
# 2  https://www.ghanaweb.com/GhanaHomePage/NewsArc...
# 3  https://www.adomonline.com/police-on-manhunt-f...
# 4  https://www.peacefmonline.com/pages/local/crim...
#
#                                              snippet        Date Region
# 0  Rampant development and soaring property price...  2023-11-27  Accra
# 1  The Achimota District Court has remanded four ...  2024-06-03  Accra
# 2  The Government of Canada has updated its Trave...  2024-01-25  Accra
# ...

# %%
Kumasi_crime_df.head(5)
# Out:
#                                                title  \
# 0  Police urged to help address juvenile crime ar...
# 1  Kumasi: Another househelp faces jail for murde...
# 2  Jirapa Dubai CEO's murder case transferred to ...
# 3                    Manso Nkran Gets Police Station
# 4  Domestic staff for Kumasi wey land court say e...
#
#                                                  url  \
# 0  https://gna.org.gh/2023/10/police-urged-to-hel...
# 1  https://www.asaaseradio.com/kumasi-another-hou...
# 2  https://www.adomonline.com/jirapa-dubai-ceos-m...
# 3  https://dailyguidenetwork.com/manso-nkran-gets...
# 4   https://www.bbc.com/pidgin/articles/cp61dp1gl62o
#
#                                              snippet        Date   Region
# 0  By Dorothy Frances Ward. Kumasi, Oct 19, GNA –...  2023-10-19  Ashanti
# 1  The suspect made a second appearance before th...  2024-01-18  Ashanti
# 2  Residents of Jirapa in the Upper West Region h...  2024-06-03  Ashanti
# ...

# %%
Kumasi_crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    88 non-null     object
#  1   url      88 non-null     object
#  2   snippet  88 non-null     object
#  3   Date     88 non-null     object
#  4   Region   88 non-null     object
# dtypes: object(5)
# memory usage: 3.6+ KB

# %%
Accra_crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    79 non-null     object
#  1   url      79 non-null     object
#  2   snippet  79 non-null     object
#  3   Date     79 non-null     object
#  4   Region   79 non-null     object
# dtypes: object(5)
# memory usage: 3.2+ KB

# %%
crimes_df=pd.concat([Kumasi_crime_df,Accra_crime_df])
crimes_df
# Out:
#                                                 title  \
# 0   Police urged to help address juvenile crime ar...
# 1   Kumasi: Another househelp faces jail for murde...
# 2   Jirapa Dubai CEO's murder case transferred to ...
# 3                     Manso Nkran Gets Police Station
# 4   Domestic staff for Kumasi wey land court say e...
# ..                                                ...
# 74                   Mass Promotion In Police Service
# 75  Macbaron Hotel Manager Grabbed For Killing Clo...
# 76   10 Most Dangerous Cities in Ghana (2024 Updated)
# 77           10 Safest Cities in Ghana (2024 Updated)
# 78  Uber & Bolt drivers, Tonaton & Jiji users blac...
#
#                                                   url  \
# 0   https://gna.org.gh/2023/10/police-urged-to-hel...
# 1   https://www.asaaseradio.com/kumasi-another-hou...
# 2   https://www.adomonline.com/jirapa-dubai-ceos-m...
# 3   https://dailyguidenetwork.com/manso-nkran-gets...
# ...
