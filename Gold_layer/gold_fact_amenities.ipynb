# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your connection details
server = 'ctrt-sqlserver.database.windows.net'
database = 'ctrt-sqldb'
username = 'CTRT-admin'
password = 'Hso2Ghana'
hospitals_Kumasi = 'silver.SO_Hospitals_Kumasi'
hospitals_Accra = 'silver.MG_Hospitals_Accra'
Churches_Accra = 'silver.KS_Churches_Accra'
Churches_Kumasi = 'silver.MG_Churches_Kumasi'
Highschools_Kumasi = 'silver.MG_Highschools_Kumasi'
Highschools_Accra = 'silver.SA_Greater_Accra_High_School'
port = '1433'  # Default is 1433, e.g., '1433'

# Create the connection string for SQLAlchemy
connection_string = (
    f"mssql+pyodbc://{username}:{password}@{server}:{port}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# Establish the connection using SQLAlchemy create_engine
engine = create_engine(connection_string, echo=False)  # Set echo=True for debugging

# Define the query
query1 = f"SELECT * FROM {hospitals_Kumasi}"
query2 = f"SELECT * FROM {hospitals_Accra}"
query3 = f"SELECT * FROM {Churches_Accra}"
query4 = f"SELECT * FROM {Churches_Kumasi}"
query5 = f"SELECT * FROM {Highschools_Accra}"
query6 = f"SELECT * FROM {Highschools_Kumasi}"

# Execute the query and load the data into a DataFrame
hospitals_accra_df = pd.read_sql(query2, engine)
hospitals_kumasi_df = pd.read_sql(query1, engine)
churches_accra_df = pd.read_sql(query3, engine)
churches_kumasi_df = pd.read_sql(query4, engine)
highschools_accra_df = pd.read_sql(query5, engine)
highschools_kumasi_df = pd.read_sql(query6, engine)

# %%
hospitals_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Domain                          23 non-null     object
#  1   Title                           103 non-null    object
#  2   Rating_value                    99 non-null     float64
#  3   Rating_votes_count              99 non-null     float64
#  4   Address                         100 non-null    object
#  5   Phone                           83 non-null     object
#  6   Category                        100 non-null    object
#  7   Latitude                        100 non-null    float64
#  8   Longitude                       100 non-null    float64
#  9   Address_info_address            73 non-null     object
#  10  Address_info_city               100 non-null    object
#  11  Address_info_country_code       100 non-null    object
# ...

# %%
hospitals_kumasi_df.drop(columns=["Domain","Rating_votes_count","Phone","Latitude","Longitude","Address_info_address","Address_info_city","Address_info_country_code",
                                  "Work_hours_timetable_sunday","Work_hours_timetable_monday","Work_hours_timetable_tuesday","Work_hours_timetable_wednesday",
                                  "Work_hours_timetable_thursday","Work_hours_timetable_friday","Work_hours_timetable_saturday","Work_hours_timetable"],axis=1,inplace=True)

# %%
hospitals_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         103 non-null    object
#  1   Rating_value  99 non-null     float64
#  2   Address       100 non-null    object
#  3   Category      100 non-null    object
#  4   Region        103 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 4.2+ KB

# %%
import numpy as np
conditions = [
    hospitals_kumasi_df["Rating_value"] >= 4.0,
    (hospitals_kumasi_df["Rating_value"] >= 3.0) & (hospitals_kumasi_df["Rating_value"] < 4.0)
]

choices = [
    "High",
    "Medium"
]

# Apply conditions using numpy select
hospitals_kumasi_df["Rate"] = np.select(conditions, choices, default="Low")

# %%
hospitals_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       100 non-null    object
#  1   Address    100 non-null    object
#  2   Phone      94 non-null     object
#  3   Category   100 non-null    object
#  4   Latitude   100 non-null    float64
#  5   Longitude  100 non-null    float64
#  6   Rating     100 non-null    float64
#  7   Rate       100 non-null    object
#  8   Region     98 non-null     object
#  9   Town       86 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
hospitals_accra_df.drop(columns=["Phone","Latitude","Longitude",],axis=1,inplace=True)

# %%
hospitals_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      100 non-null    object
#  1   Address   100 non-null    object
#  2   Category  100 non-null    object
#  3   Rating    100 non-null    float64
#  4   Rate      100 non-null    object
#  5   Region    98 non-null     object
#  6   Town      86 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.6+ KB

# %%
hospitals_accra_df.drop(columns=["Town"],axis=1,inplace=True)

# %%
hospitals_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      100 non-null    object
#  1   Address   100 non-null    object
#  2   Category  100 non-null    object
#  3   Rating    100 non-null    float64
#  4   Rate      100 non-null    object
#  5   Region    98 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %% [markdown]
# hospitals_kumasi_df.info()

# %%
churches_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Church_Name        100 non-null    object
#  1   Church_Address     100 non-null    object
#  2   Phone              74 non-null     object
#  3   Category           100 non-null    object
#  4   Latitude           100 non-null    float64
#  5   Longitude          100 non-null    float64
#  6   Rating             100 non-null    float64
#  7   Town               96 non-null     object
#  8   Region             100 non-null    object
#  9   Work_Hours_Status  100 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
churches_accra_df.drop(columns=["Phone","Latitude","Longitude","Town","Work_Hours_Status"],axis=1,inplace=True)

# %%
churches_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Church_Name     100 non-null    object
#  1   Church_Address  100 non-null    object
#  2   Category        100 non-null    object
#  3   Rating          100 non-null    float64
#  4   Region          100 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 4.0+ KB

# %%
import numpy as np
conditions = [
    churches_accra_df["Rating"] >= 4.0,
    (churches_accra_df["Rating"] >= 3.0) & (churches_accra_df["Rating"] < 4.0)
]

choices = [
    "High",
    "Medium"
]

# Apply conditions using numpy select
churches_accra_df["Rate"] = np.select(conditions, choices, default="Low")

# %%
churches_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       100 non-null    object
#  1   Address    100 non-null    object
#  2   Phone      53 non-null     object
#  3   Category   100 non-null    object
#  4   Latitude   100 non-null    float64
#  5   Longitude  100 non-null    float64
#  6   Rating     99 non-null     float64
#  7   Rate       100 non-null    object
#  8   Region     100 non-null    object
#  9   Town       35 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
churches_kumasi_df.drop(columns=["Phone","Latitude","Longitude","Town"],axis=1,inplace=True)

# %%
churches_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      100 non-null    object
#  1   Address   100 non-null    object
#  2   Category  100 non-null    object
#  3   Rating    99 non-null     float64
#  4   Rate      100 non-null    object
#  5   Region    100 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %%
highschools_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         100 non-null    object
#  1   Address       99 non-null     object
#  2   Category      100 non-null    object
#  3   Rating_value  99 non-null     float64
#  4   Region        100 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 4.0+ KB

# %%
highschools_accra_df.head()
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region
# 0  Senior high school           4.2   Greater Accra
# 1  Senior high school           4.3   Greater Accra
# 2  Senior high school           4.5   Greater Accra
# 3  Senior high school           4.4   Greater Accra
# 4  Senior high school           4.4   Greater Accra

# %%
import numpy as np
conditions = [
    highschools_accra_df["Rating_value"] >= 4.0,
    (highschools_accra_df["Rating_value"] >= 3.0) & (highschools_accra_df["Rating_value"] < 4.0)
]

choices = [
    "High",
    "Medium"
]

# Apply conditions using numpy select
highschools_accra_df["Rate"] = np.select(conditions, choices, default="Low")

# %%
highschools_accra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         100 non-null    object
#  1   Address       99 non-null     object
#  2   Category      100 non-null    object
#  3   Rating_value  99 non-null     float64
#  4   Region        100 non-null    object
#  5   Rate          100 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %%
highschools_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       100 non-null    object
#  1   Address    99 non-null     object
#  2   Phone      74 non-null     object
#  3   Category   100 non-null    object
#  4   Latitude   100 non-null    float64
#  5   Longitude  100 non-null    float64
#  6   Rating     100 non-null    float64
#  7   Rate       100 non-null    object
#  8   Region     100 non-null    object
#  9   Town       36 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
highschools_kumasi_df.drop(columns=["Phone","Latitude","Longitude","Town"],axis=1,inplace=True)

# %%
highschools_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      100 non-null    object
#  1   Address   99 non-null     object
#  2   Category  100 non-null    object
#  3   Rating    100 non-null    float64
#  4   Rate      100 non-null    object
#  5   Region    100 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %%
hospitals_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         103 non-null    object
#  1   Rating_value  99 non-null     float64
#  2   Address       100 non-null    object
#  3   Category      100 non-null    object
#  4   Region        103 non-null    object
#  5   Rate          103 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 5.0+ KB

# %%
hospitals_kumasi_df.rename(columns={"Rating_value":"Rating","Title":"Name"},inplace=True)

# %%
hospitals_kumasi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      103 non-null    object
#  1   Rating    99 non-null     float64
#  2   Address   100 non-null    object
#  3   Category  100 non-null    object
#  4   Region    103 non-null    object
#  5   Rate      103 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 5.0+ KB

# %%
hospitals_kumasi_df.head(5)
# Out:
#                                Name  Rating                        Address  \
# 0               Mount Zion Hospital     5.0                           None
# 1    Komfo Anokye Teaching Hospital     4.1     Okomfo Anokye Road, Kumasi
# 2             Kumasi South Hospital     3.7               MC27+GC3, Kumasi
# 3  Asafo-Boakye Specialist Hospital     4.4  10 Dr Asafo Boakye St, Kumasi
# 4                 Adiebeba Hospital     4.3          4 Melcom Road, Kumasi
#
#    Category          Region    Rate
# 0      None  Ashanti Region    High
# 1  Hospital  Ashanti Region    High
# 2  Hospital  Ashanti Region  Medium
# 3  Hospital  Ashanti Region    High
# 4  Hospital  Ashanti Region    High

# %%
hospitals_kumasi_df=hospitals_kumasi_df.reindex(columns=['Name', 'Address', 'Category','Rating', 'Rate', 'Region'])
hospitals_kumasi_df.head(5)
# Out:
#                                Name                        Address  Category  \
# 0               Mount Zion Hospital                           None      None
# 1    Komfo Anokye Teaching Hospital     Okomfo Anokye Road, Kumasi  Hospital
# 2             Kumasi South Hospital               MC27+GC3, Kumasi  Hospital
# 3  Asafo-Boakye Specialist Hospital  10 Dr Asafo Boakye St, Kumasi  Hospital
# 4                 Adiebeba Hospital          4 Melcom Road, Kumasi  Hospital
#
#    Rating    Rate          Region
# 0     5.0    High  Ashanti Region
# 1     4.1    High  Ashanti Region
# 2     3.7  Medium  Ashanti Region
# 3     4.4    High  Ashanti Region
# 4     4.3    High  Ashanti Region

# %%
hospitals_accra_df.head(5)
# Out:
#                               Name                Address  Category  Rating  \
# 0  Greater Accra Regional Hospital       Castle Rd, Accra  Hospital     4.2
# 1             Accra Medical Centre     6 Angola Ln, Accra  Hospital     4.0
# 2       MAB International Hospital   Nii Kpakpa St, Accra  Hospital     4.2
# 3   Trust Specialist Hospital, Osu     1 Sunkwa Rd, Accra  Hospital     4.3
# 4       Korle Bu Teaching Hospital  Guggisberg Ave, Accra  Hospital     4.1
#
#    Rate Region
# 0  High  Accra
# 1  High  Accra
# 2  High  Accra
# 3  High  Accra
# 4  High  Accra

# %%
churches_accra_df.head(5)
# Out:
#                              Church_Name  \
# 0              C3 Hope City Church Accra
# 1                           Ridge Church
# 2       Elim International Family Church
# 3  International Church of Christ, Accra
# 4       St. Paul's Roman Catholic Church
#
#                            Church_Address                   Category  Rating  \
# 0  Asoyi Crescent, La-Bawaleshi Rd, Accra                     Church     4.8
# 1                                   Accra  Non-denominational church     4.5
# 2                         MV82+7P6, Accra                     Church     4.7
# 3                         HV96+X4F, Accra           Church of Christ     5.0
# 4                         HQPP+48F, Accra            Catholic church     4.5
#
#           Region  Rate
# 0  Greater Accra  High
# 1  Greater Accra  High
# 2  Greater Accra  High
# 3  Greater Accra  High
# 4  Greater Accra  High

# %%
churches_accra_df.rename(columns={"Church_Name":"Name","Church_Address":"Address"},inplace=True)
churches_accra_df=churches_accra_df.reindex(columns=['Name', 'Address', 'Category','Rating', 'Rate', 'Region'])
churches_accra_df.head(5)
# Out:
#                                     Name  \
# 0              C3 Hope City Church Accra
# 1                           Ridge Church
# 2       Elim International Family Church
# 3  International Church of Christ, Accra
# 4       St. Paul's Roman Catholic Church
#
#                                   Address                   Category  Rating  \
# 0  Asoyi Crescent, La-Bawaleshi Rd, Accra                     Church     4.8
# 1                                   Accra  Non-denominational church     4.5
# 2                         MV82+7P6, Accra                     Church     4.7
# 3                         HV96+X4F, Accra           Church of Christ     5.0
# 4                         HQPP+48F, Accra            Catholic church     4.5
#
#    Rate         Region
# 0  High  Greater Accra
# 1  High  Greater Accra
# 2  High  Greater Accra
# 3  High  Greater Accra
# 4  High  Greater Accra

# %%
churches_kumasi_df.head(5)
# Out:
#                                         Name  \
# 0  Calvary Charismatic Centre (Headquarters)
# 1                   First Love Church Kumasi
# 2    Deeper Life Bible Church - Kumasi South
# 3           Saint Peter's Cathedral Basilica
# 4                        St. George's Church
#
#                                       Address            Category  Rating  \
# 0  Calvary Charismatic Centre, Ayigya, Kumasi  Pentecostal church     4.7
# 1              MFG8+86V, Unnamed Road, Kumasi              Church     4.7
# 2                                      Kumasi              Church     4.5
# 3                  M9VJ+XM Roman Hill, Kumasi  Catholic cathedral     4.4
# 4               M9RF+7FF, Fuller Road, Kumasi              Church     4.2
#
#    Rate   Region
# 0  High  Ashanti
# 1  High  Ashanti
# 2  High  Ashanti
# 3  High  Ashanti
# 4  High  Ashanti

# %%
highschools_kumasi_df.head(5)
# Out:
#                                   Name            Address     Category  \
# 0          St Louis Senior High School             Kumasi  High school
# 1                Asanteman Senior High             Kumasi       School
# 2         Osei Tutu Senior High School   Akropong, Kumasi  High school
# 3  Nkawie Senior High Technical School  Nkawie Rd, Kumasi    Technical
# 4        Adu Gyamfi Senior High School      Road, Gyamase       School
#
#    Rating  Rate   Region
# 0     4.4  High  Ashanti
# 1     4.2  High  Ashanti
# 2     4.4  High  Ashanti
# 3     4.2  High  Ashanti
# 4     4.3  High  Ashanti

# %%
highschools_accra_df.head(5)
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region  Rate
# 0  Senior high school           4.2   Greater Accra  High
# 1  Senior high school           4.3   Greater Accra  High
# 2  Senior high school           4.5   Greater Accra  High
# 3  Senior high school           4.4   Greater Accra  High
# 4  Senior high school           4.4   Greater Accra  High

# %%
highschools_accra_df=highschools_accra_df

# %%
highschools_accra_df.head(5)
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region  Rate
# 0  Senior high school           4.2   Greater Accra  High
# 1  Senior high school           4.3   Greater Accra  High
# 2  Senior high school           4.5   Greater Accra  High
# 3  Senior high school           4.4   Greater Accra  High
# 4  Senior high school           4.4   Greater Accra  High

# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your connection details
server = 'ctrt-sqlserver.database.windows.net'
database = 'ctrt-sqldb'
username = 'CTRT-admin'
password = 'Hso2Ghana'
Highschools_Accra = 'silver.SA_Greater_Accra_High_School'
port = '1433'  # Default is 1433, e.g., '1433'

# Create the connection string for SQLAlchemy
connection_string = (
    f"mssql+pyodbc://{username}:{password}@{server}:{port}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# Establish the connection using SQLAlchemy create_engine
engine = create_engine(connection_string, echo=False)  # Set echo=True for debugging

# Define the query
query = f"SELECT * FROM {Highschools_Accra}"

# Execute the query and load the data into a DataFrame
df = pd.read_sql(query, engine)

# %%
df.head(5)
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region
# 0  Senior high school           4.2   Greater Accra
# 1  Senior high school           4.3   Greater Accra
# 2  Senior high school           4.5   Greater Accra
# 3  Senior high school           4.4   Greater Accra
# 4  Senior high school           4.4   Greater Accra

# %%
highschools_accra_df=df

# %%
highschools_accra_df.head(5)
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region
# 0  Senior high school           4.2   Greater Accra
# 1  Senior high school           4.3   Greater Accra
# 2  Senior high school           4.5   Greater Accra
# 3  Senior high school           4.4   Greater Accra
# 4  Senior high school           4.4   Greater Accra

# %%
import numpy as np
conditions = [
    highschools_accra_df["Rating_value"] >= 4.0,
    (highschools_accra_df["Rating_value"] >= 3.0) & (highschools_accra_df["Rating_value"] < 4.0)
]

choices = [
    "High",
    "Medium"
]

# Apply conditions using numpy select
highschools_accra_df["Rate"] = np.select(conditions, choices, default="Low")

# %%
highschools_accra_df.head(5)
# Out:
#                             Title                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating_value          Region  Rate
# 0  Senior high school           4.2   Greater Accra  High
# 1  Senior high school           4.3   Greater Accra  High
# 2  Senior high school           4.5   Greater Accra  High
# 3  Senior high school           4.4   Greater Accra  High
# 4  Senior high school           4.4   Greater Accra  High

# %%
highschools_accra_df.rename(columns={"Title":"Name","Rating_value":"Rating"},inplace=True)
highschools_accra_df=highschools_accra_df.reindex(columns=['Name', 'Address', 'Category','Rating', 'Rate', 'Region'])
highschools_accra_df.head(5)
# Out:
#                              Name                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating  Rate          Region
# 0  Senior high school     4.2  High   Greater Accra
# 1  Senior high school     4.3  High   Greater Accra
# 2  Senior high school     4.5  High   Greater Accra
# 3  Senior high school     4.4  High   Greater Accra
# 4  Senior high school     4.4  High   Greater Accra

# %%
amenities_df=pd.concat([highschools_accra_df,highschools_kumasi_df,churches_accra_df,churches_kumasi_df,hospitals_accra_df,hospitals_kumasi_df])
amenities_df.head(5)
# Out:
#                              Name                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating  Rate          Region
# 0  Senior high school     4.2  High   Greater Accra
# 1  Senior high school     4.3  High   Greater Accra
# 2  Senior high school     4.5  High   Greater Accra
# 3  Senior high school     4.4  High   Greater Accra
# 4  Senior high school     4.4  High   Greater Accra

# %%
amenities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 603 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      603 non-null    object
#  1   Address   598 non-null    object
#  2   Category  600 non-null    object
#  3   Rating    597 non-null    float64
#  4   Rate      603 non-null    object
#  5   Region    601 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 33.0+ KB

# %%
amenities_df.Region.unique()
# Out:
# array([' Greater Accra', 'Ashanti', 'Greater Accra', 'Accra', 'Achimota',
#        'Lapaz', 'Swanlake', None, 'Madina', 'Lashibi', 'Tsuibleoo',
#        'Powerland', 'Mallam', 'Adenta Municipality', 'Obuasi',
#        'Ashanti Region'], dtype=object)

# %%
df1=amenities_df

# %%
df1.head(5)
# Out:
#                              Name                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating  Rate          Region
# 0  Senior high school     4.2  High   Greater Accra
# 1  Senior high school     4.3  High   Greater Accra
# 2  Senior high school     4.5  High   Greater Accra
# 3  Senior high school     4.4  High   Greater Accra
# 4  Senior high school     4.4  High   Greater Accra

# %%
amenities_df.loc[amenities_df["Region"] == "Ashanti", "Region"] = "Ashanti Region"

# %%
amenities_df.Region.unique()
# Out:
# array([' Greater Accra', 'Ashanti Region', 'Greater Accra', 'Accra',
#        'Achimota', 'Lapaz', 'Swanlake', None, 'Madina', 'Lashibi',
#        'Tsuibleoo', 'Powerland', 'Mallam', 'Adenta Municipality',
#        'Obuasi'], dtype=object)

# %%
amenities_df.loc[amenities_df["Region"] == " Greater Accra", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Accra", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Achimota", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Lapaz", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Swanlake", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Madina", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Lashibi", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Tsuibleoo", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Powerland", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Mallam", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Adenta Municipality", "Region"] = "Greater Accra Region"

# %%
amenities_df.loc[amenities_df["Region"] == "Obuasi", "Region"] = "Ashanti Region"

# %%
amenities_df.Region.unique()
# Out:
# array(['Greater Accra Region', 'Ashanti Region', 'Greater Accra', None],
#       dtype=object)

# %%
amenities_df.loc[amenities_df["Region"] == "Greater Accra", "Region"] = "Greater Accra Region"

# %%
amenities_df.Region.unique()
# Out:
# array(['Greater Accra Region', 'Ashanti Region', None], dtype=object)

# %%
amenities_df.Category.unique()
# Out:
# array(['Senior high school', 'School', 'High school', 'Middle school',
#        'International school', 'Educational institution',
#        'Primary school', 'Private educational institution',
#        'Elementary school', 'Technical', 'Catholic', 'Catholic school',
#        'Higher secondary school', "Girls' high school", 'Church',
#        'Non-denominational church', 'Church of Christ', 'Catholic church',
#        'Presbyterian church', 'Methodist church', 'Parish',
#        'Anglican church', 'Baptist church', 'Gospel church',
#        'Apostolic church', 'Pentecostal church',
#        'Church of Jesus Christ of Latter-day Saints', 'Christian church',
#        'Seventh-day Adventist church', 'Church of the Nazarene',
#        'Catholic cathedral', 'Evangelical church', 'Place of worship',
#        'Congregation', 'United Church of Christ',
#        'Assemblies of God church', 'Recruiter', 'Chapel', 'Hospital',
#        'Government hospital', "Children's hospital",
# ...

# %%
from datetime import datetime
amenities_df["Date"]=datetime.today().date()

# %%
amenities_df.head(5)
# Out:
#                              Name                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating  Rate                Region        Date
# 0  Senior high school     4.2  High  Greater Accra Region  2024-07-11
# 1  Senior high school     4.3  High  Greater Accra Region  2024-07-11
# 2  Senior high school     4.5  High  Greater Accra Region  2024-07-11
# 3  Senior high school     4.4  High  Greater Accra Region  2024-07-11
# 4  Senior high school     4.4  High  Greater Accra Region  2024-07-11

# %%
import numpy as np
conditions = [
    amenities_df["Category"].str.contains("school|institution", case=False, na=False),
    amenities_df["Category"].str.contains("church|chapel|worship|congregation", case=False, na=False),
    amenities_df["Category"].str.contains("hospital|medical center|clinic", case=False, na=False),
]

choices = [
    "School",
    "Church",
    "Hospital",
]

# Apply conditions using numpy select
amenities_df["Type"] = np.select(conditions, choices, default="Other")

# %%
amenities_df
# Out:
#                                          Name  \
# 0                  Odorgonno Secondary School
# 1              Accra Girls Senior High School
# 2                               Accra Academy
# 3               St. Mary's Senior High School
# 4                   Labone Senior High School
# ..                                        ...
# 98      Marie Stopes Clinic, Santasi - Kumasi
# 99                       Rabito Clinic Kumasi
# 100  Alternative medicine specialist Hospital
# 101                Mary Pomaa Memorial Clinic
# 102                       Anwiam Clinic Annex
#
#                                              Address            Category  \
# 0                            Anyaa-Awoshie Rd, Accra  Senior high school
# 1                        Olusegun Obasanjo Wy, Accra  Senior high school
# 2                               Dr. Busia Hwy, Accra  Senior high school
# 3             GQPG+8QC, Nii Tackie Owuowuo St, Accra  Senior high school
# ...

# %%
amenities_df.head(5)
# Out:
#                              Name                                 Address  \
# 0      Odorgonno Secondary School                 Anyaa-Awoshie Rd, Accra
# 1  Accra Girls Senior High School             Olusegun Obasanjo Wy, Accra
# 2                   Accra Academy                    Dr. Busia Hwy, Accra
# 3   St. Mary's Senior High School  GQPG+8QC, Nii Tackie Owuowuo St, Accra
# 4       Labone Senior High School           Josiah Tongoogari Link, Accra
#
#              Category  Rating  Rate                Region        Date    Type
# 0  Senior high school     4.2  High  Greater Accra Region  2024-07-11  School
# 1  Senior high school     4.3  High  Greater Accra Region  2024-07-11  School
# 2  Senior high school     4.5  High  Greater Accra Region  2024-07-11  School
# 3  Senior high school     4.4  High  Greater Accra Region  2024-07-11  School
# 4  Senior high school     4.4  High  Greater Accra Region  2024-07-11  School

# %%
new_schema = 'gold'
new_table_name = 'MG_Fact_Amenities'

# Write DataFrame to the new table in the specified schema in the database
amenities_df.to_sql(new_table_name, engine, schema=new_schema, if_exists='replace', index=False)

print(f"Data written to {new_schema}.{new_table_name} successfully.")
# Out:
# Data written to gold.MG_Fact_Amenities successfully.
