# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your connection details
server = 'ctrt-sqlserver.database.windows.net'
database = 'ctrt-sqldb'
username = 'CTRT-admin'
password = 'Hso2Ghana'
table_name = 'bronze.MG_Hospitals_Accra' 
port = '1433'  # Default is 1433, e.g., '1433'

# Create the connection string for SQLAlchemy
connection_string = (
    f"mssql+pyodbc://{username}:{password}@{server}:{port}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# Establish the connection using SQLAlchemy create_engine
engine = create_engine(connection_string, echo=False)  # Set echo=True for debugging

# Define the query
query = f"SELECT * FROM {table_name}"

# Execute the query and load the data into a DataFrame
df = pd.read_sql(query, engine)

# %%
pd.set_option('display.max_columns',None)
df.head(5)
# Out:
#           type  rank_group  rank_absolute                    domain  \
# 0  maps_search           1              1                      None
# 1  maps_search           2              2          www.accramed.com
# 2  maps_search           3              3      www.mabhospitals.org
# 3  maps_search           4              4  www.thetrusthospital.com
# 4  maps_search           5              5           www.kbth.gov.gh
#
#                              title                               url  \
# 0  Greater Accra Regional Hospital                              None
# 1             Accra Medical Centre         https://www.accramed.com/
# 2       MAB International Hospital      http://www.mabhospitals.org/
# 3   Trust Specialist Hospital, Osu  http://www.thetrusthospital.com/
# 4       Korle Bu Teaching Hospital           http://www.kbth.gov.gh/
#
#   contact_url hotel_rating price_level                snippet  \
# 0        None         None        None       Castle Rd, Accra
# 1        None         None        None     6 Angola Ln, Accra
# 2        None         None        None   Nii Kpakpa St, Accra
# 3        None         None        None     1 Sunkwa Rd, Accra
# 4        None         None        None  Guggisberg Ave, Accra
#
#                  address                     place_id          phone  \
# 0       Castle Rd, Accra  ChIJN5yfMHaa3w8RdnVUzz6HULQ  +233247814770
# 1     6 Angola Ln, Accra  ChIJRRk7bIea3w8RF33vwFtUqmU  +233204096099
# 2   Nii Kpakpa St, Accra  ChIJbZmHn6mZ3w8Rw3Hvidjf1xY  +233209494300
# 3     1 Sunkwa Rd, Accra  ChIJvcQh4n-Q3w8RZnMUVR-1c4Y  +233302797147
# 4  Guggisberg Ave, Accra  ChIJmcgvVTSX3w8RJq690GBuuXM  +233302739510
#
#                                           main_image  total_photos  category  \
# 0  https://lh5.googleusercontent.com/p/AF1QipPrxk...         570.0  Hospital
# 1  https://lh5.googleusercontent.com/p/AF1QipOo4m...          59.0  Hospital
# 2  https://lh5.googleusercontent.com/p/AF1QipMkHx...          50.0  Hospital
# 3  https://lh5.googleusercontent.com/p/AF1QipOZhV...          98.0  Hospital
# 4  https://lh5.googleusercontent.com/p/AF1QipNNzF...        1012.0  Hospital
#
#   additional_categories category_ids                            feature_id  \
# 0                  None               0xfdf9a76309f9c37:0xb450873ecf547576
# 1                  None               0xfdf9a876c3b1945:0x65aa545bc0ef7d17
# 2                  None               0xfdf99a99f87996d:0x16d7dfd889ef71c3
# 3                  None               0xfdf907fe221c4bd:0x8673b51f55147366
# 4                  None               0xfdf9734552fc899:0x73b96e60d0bdae26
#
#                     cid  latitude  longitude  is_claimed local_justifications  \
# 0  12993033628800021878  5.561373  -0.198676        True                 None
# 1   7325760496927210775  5.568699  -0.186040       False                 None
# 2   1646030309947306435  5.601313  -0.256759        True                 None
# 3   9688286369580086118  5.560744  -0.187220        True                 None
# 4   8338817547151191590  5.536607  -0.226409        True                 None
#
#    is_directory_item rating_rating_type  rating_value  rating_votes_count  \
# 0              False               Max5           4.2                 304
# 1              False               Max5           4.0                  66
# 2              False               Max5           4.2                  35
# 3              False               Max5           4.3                  48
# 4              False               Max5           4.1                 427
#
#   rating_rating_max  rating_distribution_1  rating_distribution_2  \
# 0              None                     20                      9
# 1              None                     14                      0
# 2              None                      4                      0
# 3              None                      3                      0
# 4              None                     26                     13
#
#    rating_distribution_3  rating_distribution_4  rating_distribution_5  \
# 0                     31                     64                    180
# 1                      2                      6                     44
# 2                      2                      9                     20
# 3                      5                     13                     27
# 4                     57                    113                    218
#
#   address_info_borough address_info_address address_info_city  \
# 0          Osu Klottey            Castle Rd             Accra
# 1          Osu Klottey          6 Angola Ln             Accra
# 2        Okaikoi South        Nii Kpakpa St             Accra
# 3          Osu Klottey          1 Sunkwa Rd             Accra
# 4             Ablekuma       Guggisberg Ave             Accra
#
#   address_info_zip address_info_region address_info_country_code  \
# 0             None                None                        GH
# 1             None                None                        GH
# 2             None                None                        GH
# 3             None                None                        GH
# 4             None                None                        GH
#
#   work_hours_timetable_sunday work_hours_timetable_monday  \
# 0
# 1
# 2
# 3                        None
# 4
#
#   work_hours_timetable_tuesday work_hours_timetable_wednesday  \
# 0
# 1
# 2
# 3
# 4
#
#   work_hours_timetable_thursday work_hours_timetable_friday  \
# 0
# 1
# 2
# 3
# 4
#
#   work_hours_timetable_saturday work_hours_current_status work_hours_timetable
# 0                                                    open                 None
# 1                                                    open                 None
# 2                                                    open                 None
# 3                                                    open                 None
# 4                                                    open                 None

# %%
df.drop(columns=['type', 'rank_group', 'rank_absolute','domain','contact_url', 'hotel_rating', 'price_level', 'snippet','place_id','main_image', 'total_photos',
                    'additional_categories', 'category_ids', 'feature_id', 'cid','is_claimed', 'local_justifications','is_directory_item', 'rating_rating_type',
                    'rating_votes_count', 'rating_rating_max', 'rating_distribution_1','rating_distribution_2', 'rating_distribution_3','rating_distribution_4',
                    'rating_distribution_5','address_info_address', 'address_info_zip', 'address_info_region', 'address_info_country_code',
                    'work_hours_timetable_sunday', 'work_hours_timetable_monday','work_hours_timetable_tuesday', 'work_hours_timetable_wednesday','work_hours_timetable_thursday', 'work_hours_timetable_friday',
                    'work_hours_timetable_saturday', 'work_hours_current_status','work_hours_timetable'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'url', 'address', 'phone', 'category', 'latitude', 'longitude',
#        'rating_value', 'address_info_borough', 'address_info_city'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 100 non-null    object
#  1   url                   47 non-null     object
#  2   address               100 non-null    object
#  3   phone                 94 non-null     object
#  4   category              100 non-null    object
#  5   latitude              100 non-null    float64
#  6   longitude             100 non-null    float64
#  7   rating_value          100 non-null    float64
#  8   address_info_borough  86 non-null     object
#  9   address_info_city     98 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
df.head(5)
# Out:
#                              title                               url  \
# 0  Greater Accra Regional Hospital                              None
# 1             Accra Medical Centre         https://www.accramed.com/
# 2       MAB International Hospital      http://www.mabhospitals.org/
# 3   Trust Specialist Hospital, Osu  http://www.thetrusthospital.com/
# 4       Korle Bu Teaching Hospital           http://www.kbth.gov.gh/
#
#                  address          phone  category  latitude  longitude  \
# 0       Castle Rd, Accra  +233247814770  Hospital  5.561373  -0.198676
# 1     6 Angola Ln, Accra  +233204096099  Hospital  5.568699  -0.186040
# 2   Nii Kpakpa St, Accra  +233209494300  Hospital  5.601313  -0.256759
# 3     1 Sunkwa Rd, Accra  +233302797147  Hospital  5.560744  -0.187220
# 4  Guggisberg Ave, Accra  +233302739510  Hospital  5.536607  -0.226409
#
#    rating_value address_info_borough address_info_city
# 0           4.2          Osu Klottey             Accra
# 1           4.0          Osu Klottey             Accra
# 2           4.2        Okaikoi South             Accra
# 3           4.3          Osu Klottey             Accra
# 4           4.1             Ablekuma             Accra

# %%
df.rename(columns={"title":"Name","address":"Address","phone":"Phone","category":"Category","latitude":"Latitude","longitude":"Longitude","rating_value":"Rating","address_info_borough":"Town"},inplace=True)

# %%
df.head(5)
# Out:
#                               Name                               url  \
# 0  Greater Accra Regional Hospital                              None
# 1             Accra Medical Centre         https://www.accramed.com/
# 2       MAB International Hospital      http://www.mabhospitals.org/
# 3   Trust Specialist Hospital, Osu  http://www.thetrusthospital.com/
# 4       Korle Bu Teaching Hospital           http://www.kbth.gov.gh/
#
#                  Address          Phone  Category  Latitude  Longitude  \
# 0       Castle Rd, Accra  +233247814770  Hospital  5.561373  -0.198676
# 1     6 Angola Ln, Accra  +233204096099  Hospital  5.568699  -0.186040
# 2   Nii Kpakpa St, Accra  +233209494300  Hospital  5.601313  -0.256759
# 3     1 Sunkwa Rd, Accra  +233302797147  Hospital  5.560744  -0.187220
# 4  Guggisberg Ave, Accra  +233302739510  Hospital  5.536607  -0.226409
#
#    Rating           Town address_info_city
# 0     4.2    Osu Klottey             Accra
# 1     4.0    Osu Klottey             Accra
# 2     4.2  Okaikoi South             Accra
# 3     4.3    Osu Klottey             Accra
# 4     4.1       Ablekuma             Accra

# %%
df.rename(columns={"address_info_city":"Region"},inplace=True)

# %%
import numpy as np
conditions = [
    df["Rating"] >= 4.0,
    (df["Rating"] >= 3.0) & (df["Rating"] < 4.0)
]

choices = [
    "High",
    "Medium"
]

# Apply conditions using numpy select
df["Rate"] = np.select(conditions, choices, default="Low")

# %%
df=df.reindex(columns=['Name', 'Address', 'Phone', 'Category', 'Latitude', 'Longitude',
       'Rating', 'Rate', 'Region', 'Town'])
df
# Out:
#                                                  Name  \
# 0                     Greater Accra Regional Hospital
# 1                                Accra Medical Centre
# 2                          MAB International Hospital
# 3                      Trust Specialist Hospital, Osu
# 4                          Korle Bu Teaching Hospital
# ..                                                ...
# 95                                        Iran Clinic
# 96             St. John's Hospital & Fertility Centre
# 97                           Hanson Memorial Hospital
# 98  Martin Memorial Hospital (Cardiovascular Centr...
# 99                                     Rophi Hospital
#
#                                        Address          Phone  Category  \
# 0                             Castle Rd, Accra  +233247814770  Hospital
# 1                           6 Angola Ln, Accra  +233204096099  Hospital
# 2                         Nii Kpakpa St, Accra  +233209494300  Hospital
# 3                           1 Sunkwa Rd, Accra  +233302797147  Hospital
# 4                        Guggisberg Ave, Accra  +233302739510  Hospital
# ..                                         ...            ...       ...
# 95                     Kojo Thompson Rd, Accra  +233302243342  Hospital
# 96                          Nsawam Road, Accra  +233501258518  Hospital
# 97                             HPJH+XGF, Accra  +233302304325  Hospital
# 98  JQ6R+H4M, Sir Emmanuel Quist Street, Accra  +233241536281  Hospital
# 99                                       Accra  +233208124185  Hospital
#
#     Latitude  Longitude  Rating    Rate Region           Town
# 0   5.561373  -0.198676     4.2    High  Accra    Osu Klottey
# 1   5.568699  -0.186040     4.0    High  Accra    Osu Klottey
# 2   5.601313  -0.256759     4.2    High  Accra  Okaikoi South
# 3   5.560744  -0.187220     4.3    High  Accra    Osu Klottey
# 4   5.536607  -0.226409     4.1    High  Accra       Ablekuma
# ..       ...        ...     ...     ...    ...            ...
# 95  5.567997  -0.212504     3.8  Medium  Accra    Osu Klottey
# 96  5.645333  -0.247638     4.1    High  Accra           Dome
# 97  5.582438  -0.271212     4.0    High  Accra       Ablekuma
# 98  5.611467  -0.209715     5.0    High  Accra        Ayawaso
# 99  5.628301  -0.080343     3.2  Medium  Accra           None
#
# [100 rows x 10 columns]

# %%
df.Category.unique()
# Out:
# array(['Hospital', 'Government hospital', "Children's hospital",
#        'Specialized hospital', 'University hospital', 'Medical Center'],
#       dtype=object)

# %%
new_schema = 'silver'
new_table_name = 'MG_Hospitals_Accra'

# Write DataFrame to the new table in the specified schema in the database
df.to_sql(new_table_name, engine, schema=new_schema, if_exists='replace', index=False)

print(f"Data written to {new_schema}.{new_table_name} successfully.")
# Out:
# Data written to silver.MG_Hospitals_Accra successfully.
